# %%
# importing all the necessary modules:-
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import statsmodels.api as sm

from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ### Exploring the dataset:

# %%
# Reading the dataset:
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# adding a constant to the independent variables:
# we are adding a constant because as the line equation is y=mx+c so c is a constant which is not present in the statsmodel api.
x = sm.add_constant(x)

# %%
x
# Out:
#      const  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      1.0            6      148             72             35        0  33.6
# 1      1.0            1       85             66             29        0  26.6
# 2      1.0            8      183             64              0        0  23.3
# 3      1.0            1       89             66             23       94  28.1
# 4      1.0            0      137             40             35      168  43.1
# ..     ...          ...      ...            ...            ...      ...   ...
# 763    1.0           10      101             76             48      180  32.9
# 764    1.0            2      122             70             27        0  36.8
# 765    1.0            5      121             72             23      112  26.2
# 766    1.0            1      126             60              0        0  30.1
# 767    1.0            1       93             70             31        0  30.4
#
# ...

# %% [markdown]
# ## Splitting the dataset into Train and Test:

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=1)
print(f"Train Data: {xtrain.shape}, {ytrain.shape}")
print(f"Test Data: {xtest.shape}, {ytest.shape}")
# Out:
# Train Data: (537, 9), (537,)
# Test Data: (231, 9), (231,)

# %% [markdown]
# ## Fitting the Logistic Regression Model:-

# %%
logistic_model = sm.Logit(ytrain,xtrain) #initializing the model
trained_logistic_model = logistic_model.fit() #train the model
print(trained_logistic_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.480906
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                Outcome   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      528
# Method:                           MLE   Df Model:                            8
# Date:                Mon, 04 Sep 2023   Pseudo R-squ.:                  0.2504
# Time:                        18:01:12   Log-Likelihood:                -258.25
# converged:                       True   LL-Null:                       -344.51
# Covariance Type:            nonrobust   LLR p-value:                 3.795e-33
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
predicted_probabilities = trained_logistic_model.predict(xtest)
print(predicted_probabilities)
# Out:
# 285    0.421206
# 101    0.301760
# 581    0.144632
# 352    0.054265
# 726    0.209006
#          ...
# 241    0.116302
# 599    0.111022
# 650    0.052131
# 11     0.871773
# 214    0.301408
# Length: 231, dtype: float64

# %%
threshold = 0.5
predictions = (predicted_probabilities > threshold).astype(int)
print(predictions)
# Out:
# 285    0
# 101    0
# 581    0
# 352    0
# 726    0
#       ..
# 241    0
# 599    0
# 650    0
# 11     1
# 214    0
# Length: 231, dtype: int32

# %%
print(f"Accuracy of the model: {accuracy_score(ytest, predictions)}")
print(confusion_matrix(ytest,predictions))
# Out:
# Accuracy of the model: 0.7835497835497836
# [[132  14]
#  [ 36  49]]

# %% [raw]
# Splitting the dataset by removing non-significant independent variables:

# %%
# performing train and test split by removing the non-significant variables
xtrain,xtest,ytrain,ytest = train_test_split(x.drop(columns=["SkinThickness","Age"]),y,test_size=0.3,random_state=1)
print(f"Train Data: {xtrain.shape}, {ytrain.shape}")
print(f"Test Data: {xtest.shape}, {ytest.shape}")
# Out:
# Train Data: (537, 7), (537,)
# Test Data: (231, 7), (231,)

# %% [raw]
# Retraining the Logistic Regression

# %%
logistic_model = sm.Logit(ytrain,xtrain) #initializing the model
trained_logistic_model = logistic_model.fit() #train the model
print(trained_logistic_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.483260
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                Outcome   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      530
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 04 Sep 2023   Pseudo R-squ.:                  0.2467
# Time:                        18:01:12   Log-Likelihood:                -259.51
# converged:                       True   LL-Null:                       -344.51
# Covariance Type:            nonrobust   LLR p-value:                 4.482e-34
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
predicted_probabilities = trained_logistic_model.predict(xtest)
print(predicted_probabilities)
# Out:
# 285    0.384277
# 101    0.339932
# 581    0.171990
# 352    0.041586
# 726    0.214990
#          ...
# 241    0.134897
# 599    0.110858
# 650    0.054523
# 11     0.897381
# 214    0.318907
# Length: 231, dtype: float64

# %%
threshold = 0.5
predictions = (predicted_probabilities > threshold).astype(int)
print(predictions)
# Out:
# 285    0
# 101    0
# 581    0
# 352    0
# 726    0
#       ..
# 241    0
# 599    0
# 650    0
# 11     1
# 214    0
# Length: 231, dtype: int32

# %%
print(f"Accuracy of the model: {accuracy_score(ytest, predictions)}")
print(confusion_matrix(ytest,predictions))
# Out:
# Accuracy of the model: 0.7922077922077922
# [[133  13]
#  [ 35  50]]
